# %%
# 필요한 모듈 설치
 #사진 관련 모듈
 #인터넷 접속 관련 모듈 

# !pip install pillow
# !pip install requests
# Out:
# Requirement already satisfied: pillow in c:\users\seulki oh\anaconda3\lib\site-packages (8.0.1)
# Requirement already satisfied: requests in c:\users\seulki oh\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\seulki oh\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\seulki oh\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seulki oh\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\seulki oh\anaconda3\lib\site-packages (from requests) (3.0.4)

# %%
import matplotlib.pyplot as plt    #그림관련 모듈을 끌어 쓰겠다
import matplotlib.image as mpimg    #사진관련 모듈을 끌어 쓰겠다


# %matplotlib inline
 #생략 가능 : 브라우저 상의 표현

# %%
img = mpimg.imread('face1.jpg')
plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
#유명인 얼굴과 얼마나 비슷한지 검색

import requests  # 인터넷 연결

client_id = "JtzyEv6hdzG2mhfewvFn"
client_secret = "b7VOpgnzec"

url = "https://openapi.naver.com/v1/vision/celebrity"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %matplotlib inline

# %%
import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))

#사진 한장의 최대 크기는 2MB로 네이버에서 제한해두었다.
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "김수현",
#                 "confidence": 0.286284
#             }
#         }
#     ]
# }

# %%
# 얼굴인식, 나이 예측, 감정 상태 분석

import requests  # 인터넷 연결

client_id = "JtzyEv6hdzG2mhfewvFn"
client_secret = "b7VOpgnzec"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %matplotlib inline

# %%
import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))

#사진 한장의 최대 크기는 2MB로 네이버에서 제한해두었다.
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 272,
#                 "y": 98,
#                 "width": 113,
#                 "height": 113
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 298,
#                     "y": 124
#                 },
#                 "rightEye": {
#                     "x": 350,
#                     "y": 129
#                 },
#                 "nose": {
#                     "x": 320,
#                     "y": 157
#                 },
#                 "leftMouth": {
#                     "x": 297,
#                     "y": 182
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 186
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999998
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.441697
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 1.0
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.991977
#             }
#         }
#     ]
# }

# %%
#가족 얼굴 분석
import requests  # 인터넷 연결

client_id = "JtzyEv6hdzG2mhfewvFn"
client_secret = "b7VOpgnzec"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %matplotlib inline

# %%
import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 445,
#             "height": 630
#         },
#         "faceCount": 8
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 215,
#                 "y": 183,
#                 "width": 37,
#                 "height": 37
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 223,
#                     "y": 190
#                 },
#                 "rightEye": {
#                     "x": 242,
#                     "y": 190
#                 },
#                 "nose": {
#                     "x": 234,
#                     "y": 199
#                 },
#                 "leftMouth": {
#                     "x": 225,
#                     "y": 208
#                 },
#                 "rightMouth": {
#                     "x": 242,
#                     "y": 208
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999973
#             },
#             "age": {
#                 "value": "59~63",
#                 "confidence": 0.090468
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.99994
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999894
#             }
#         },
#         {
#             "roi": {
#                 "x": 318,
#                 "y": 162,
#                 "width": 38,
#                 "height": 38
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 328,
#                     "y": 169
#                 },
#                 "rightEye": {
#                     "x": 347,
#                     "y": 169
#                 },
#                 "nose": {
#                     "x": 339,
#                     "y": 179
#                 },
#                 "leftMouth": {
#                     "x": 331,
#                     "y": 189
#                 },
#                 "rightMouth": {
#                     "x": 344,
#                     "y": 189
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999739
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.969172
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.99715
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999808
#             }
#         },
#         {
#             "roi": {
#                 "x": 235,
#                 "y": 57,
#                 "width": 41,
#                 "height": 41
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 246,
#                     "y": 67
#                 },
#                 "rightEye": {
#                     "x": 267,
#                     "y": 66
#                 },
#                 "nose": {
#                     "x": 258,
#                     "y": 76
#                 },
#                 "leftMouth": {
#                     "x": 250,
#                     "y": 88
#                 },
#                 "rightMouth": {
#                     "x": 268,
#                     "y": 86
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.656963
#             },
#             "age": {
#                 "value": "80~84",
#                 "confidence": 0.242016
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.957067
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.979933
#             }
#         },
#         {
#             "roi": {
#                 "x": 136,
#                 "y": 136,
#                 "width": 36,
#                 "height": 36
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 144,
#                     "y": 142
#                 },
#                 "rightEye": {
#                     "x": 164,
#                     "y": 142
#                 },
#                 "nose": {
#                     "x": 155,
#                     "y": 151
#                 },
#                 "leftMouth": {
#                     "x": 147,
#                     "y": 161
#                 },
#                 "rightMouth": {
#                     "x": 163,
#                     "y": 162
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.997381
#             },
#             "age": {
#                 "value": "54~58",
#                 "confidence": 0.136841
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.996852
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.998287
#             }
#         },
#         {
#             "roi": {
#                 "x": 32,
#                 "y": 204,
#                 "width": 46,
#                 "height": 46
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 43,
#                     "y": 216
#                 },
#                 "rightEye": {
#                     "x": 64,
#                     "y": 213
#                 },
#                 "nose": {
#                     "x": 56,
#                     "y": 226
#                 },
#                 "leftMouth": {
#                     "x": 48,
#                     "y": 236
#                 },
#                 "rightMouth": {
#                     "x": 66,
#                     "y": 234
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.998743
#             },
#             "age": {
#                 "value": "27~31",
#                 "confidence": 0.210603
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.793047
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.7807
#             }
#         },
#         {
#             "roi": {
#                 "x": 204,
#                 "y": 264,
#                 "width": 32,
#                 "height": 32
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.787793
#             },
#             "age": {
#                 "value": "2~6",
#                 "confidence": 0.342641
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.944879
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.516906
#             }
#         },
#         {
#             "roi": {
#                 "x": 274,
#                 "y": 266,
#                 "width": 33,
#                 "height": 33
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 287,
#                     "y": 276
#                 },
#                 "rightEye": {
#                     "x": 299,
#                     "y": 275
#                 },
#                 "nose": {
#                     "x": 296,
#                     "y": 281
#                 },
#                 "leftMouth": {
#                     "x": 288,
#                     "y": 290
#                 },
#                 "rightMouth": {
#                     "x": 298,
#                     "y": 289
#                 }
#             },
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.611462
#             },
#             "age": {
#                 "value": "31~35",
#                 "confidence": 3.42814e-05
#             },
#             "emotion": {
#                 "value": "talking",
#                 "confidence": 0.984321
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.583783
#             }
#         },
#         {
#             "roi": {
#                 "x": 135,
#                 "y": 214,
#                 "width": 41,
#                 "height": 41
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 144,
#                     "y": 226
#                 },
#                 "rightEye": {
#                     "x": 163,
#                     "y": 227
#                 },
#                 "nose": {
#                     "x": 155,
#                     "y": 232
#                 },
#                 "leftMouth": {
#                     "x": 144,
#                     "y": 244
#                 },
#                 "rightMouth": {
#                     "x": 164,
#                     "y": 244
#                 }
#             },
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.986629
#             },
#             "age": {
#                 "value": "87~91",
#                 "confidence": 0.134264
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.714546
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999747
#             }
#         }
#     ]
# }

# %%
img = mpimg.imread('face2.jpg')
plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %% [markdown]
# # 기본 문법 학습

# %%
#dict형과 json에 대해
dict = {'Name':'pinkwink', 
        'Age':'None', 
        'Class':['beginner','blog']
       }
dict
# Out:
# {'Name': 'pinkwink', 'Age': 'None', 'Class': ['beginner', 'blog']}

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict.values()
# Out:
# dict_values(['pinkwink', 'None', ['beginner', 'blog']])

# %%
dict['Class']
# Out:
# ['beginner', 'blog']

# %%
dict.get('Name')
# Out:
# 'pinkwink'

# %%
dict.get('Age','nothing')
# Out:
# 'None'

# %%
dict.get('Room','nothing')
# Out:
# 'nothing'

# %% [markdown]
# # json ( = Java Script Object Notation)

# %%
customer = {
    'id' : '0001',
    'name': '홍길동',
    'history' : [
        {'date':'2019-03-01', 'log':True},
        {'date':'2019-03-02', 'log':False},
    ]
    
}

# %%
#위의 dict을 json으로 바꾸어준다.
import json
json_test = json.dumps(customer, indent=4, ensure_ascii=False)
print(json_test)

#ensure_ascii=False 는 문자가 깨지는걸 막아준다.
# Out:
# {
#     "id": "0001",
#     "name": "홍길동",
#     "history": [
#         {
#             "date": "2019-03-01",
#             "log": true
#         },
#         {
#             "date": "2019-03-02",
#             "log": false
#         }
#     ]
# }

# %% [markdown]
# # 사진 위에 개인 정보 표시하기

# %%
img = mpimg.imread('face1.jpg')
plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests  # 인터넷 연결

client_id = "JtzyEv6hdzG2mhfewvFn"
client_secret = "b7VOpgnzec"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
#넘겨받은 그대로, 들여쓰기도 해주고, keys값 정렬하지 말고 출력해준다.
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 272,
#                 "y": 98,
#                 "width": 113,
#                 "height": 113
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 298,
#                     "y": 124
#                 },
#                 "rightEye": {
#                     "x": 350,
#                     "y": 129
#                 },
#                 "nose": {
#                     "x": 320,
#                     "y": 157
#                 },
#                 "leftMouth": {
#                     "x": 297,
#                     "y": 182
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 186
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999998
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.441697
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 1.0
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.991977
#             }
#         }
#     ]
# }

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
parsed['faces']
# 필요한 정보만 보여준다.
# Out:
# [{'roi': {'x': 272, 'y': 98, 'width': 113, 'height': 113},
#   'landmark': {'leftEye': {'x': 298, 'y': 124},
#    'rightEye': {'x': 350, 'y': 129},
#    'nose': {'x': 320, 'y': 157},
#    'leftMouth': {'x': 297, 'y': 182},
#    'rightMouth': {'x': 343, 'y': 186}},
#   'gender': {'value': 'male', 'confidence': 0.999998},
#   'age': {'value': '30~34', 'confidence': 0.441697},
#   'emotion': {'value': 'neutral', 'confidence': 1.0},
#   'pose': {'value': 'frontal_face', 'confidence': 0.991977}}]

# %%
parsed['faces'][0]
# Out:
# {'roi': {'x': 272, 'y': 98, 'width': 113, 'height': 113},
#  'landmark': {'leftEye': {'x': 298, 'y': 124},
#   'rightEye': {'x': 350, 'y': 129},
#   'nose': {'x': 320, 'y': 157},
#   'leftMouth': {'x': 297, 'y': 182},
#   'rightMouth': {'x': 343, 'y': 186}},
#  'gender': {'value': 'male', 'confidence': 0.999998},
#  'age': {'value': '30~34', 'confidence': 0.441697},
#  'emotion': {'value': 'neutral', 'confidence': 1.0},
#  'pose': {'value': 'frontal_face', 'confidence': 0.991977}}

# %%
parsed['faces'][0]['roi']
#얼굴의 위치값
# Out:
# {'x': 272, 'y': 98, 'width': 113, 'height': 113}

# %%
parsed['faces'][0]['gender']
# Out:
# {'value': 'male', 'confidence': 0.999998}

# %%
parsed['faces'][0]['age']
# Out:
# {'value': '30~34', 'confidence': 0.441697}

# %%
parsed['faces'][0]['emotion']
# Out:
# {'value': 'neutral', 'confidence': 1.0}

# %%
x,y,w,h = parsed['faces'][0]['roi'].values()
gender,gen_confi = parsed['faces'][0]['gender'].values()
emotion,emo_confi = parsed['faces'][0]['emotion'].values()
age,age_confi = parsed['faces'][0]['age'].values()

# %%
annotation = gender + " : " + str(gen_confi) + '\n' + emotion + " : " + str(emo_confi) + '\n' + age + " ; " + str(age_confi)

# %%
print(annotation)
# Out:
# male : 0.999998
# neutral : 1.0
# 30~34 ; 0.441697

# %%
import matplotlib.patches as patches

img = mpimg.imread('face1.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

rect_face = patches.Rectangle((x,y),w,h,
                             linewidth = 5,
                             edgecolor = 'r',
                             facecolor = 'none')
ax.add_patch(rect_face)

plt.text(10,400, annotation, wrap = True, fontsize = 17, color = 'white')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
img = mpimg.imread('face2.jpg')
plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests  # 인터넷 연결

client_id = "JtzyEv6hdzG2mhfewvFn"
client_secret = "b7VOpgnzec"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 445,
#             "height": 630
#         },
#         "faceCount": 8
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 215,
#                 "y": 183,
#                 "width": 37,
#                 "height": 37
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 223,
#                     "y": 190
#                 },
#                 "rightEye": {
#                     "x": 242,
#                     "y": 190
#                 },
#                 "nose": {
#                     "x": 234,
#                     "y": 199
#                 },
#                 "leftMouth": {
#                     "x": 225,
#                     "y": 208
#                 },
#                 "rightMouth": {
#                     "x": 242,
#                     "y": 208
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999973
#             },
#             "age": {
#                 "value": "59~63",
#                 "confidence": 0.090468
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.99994
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999894
#             }
#         },
#         {
#             "roi": {
#                 "x": 318,
#                 "y": 162,
#                 "width": 38,
#                 "height": 38
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 328,
#                     "y": 169
#                 },
#                 "rightEye": {
#                     "x": 347,
#                     "y": 169
#                 },
#                 "nose": {
#                     "x": 339,
#                     "y": 179
#                 },
#                 "leftMouth": {
#                     "x": 331,
#                     "y": 189
#                 },
#                 "rightMouth": {
#                     "x": 344,
#                     "y": 189
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999739
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.969172
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.99715
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999808
#             }
#         },
#         {
#             "roi": {
#                 "x": 235,
#                 "y": 57,
#                 "width": 41,
#                 "height": 41
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 246,
#                     "y": 67
#                 },
#                 "rightEye": {
#                     "x": 267,
#                     "y": 66
#                 },
#                 "nose": {
#                     "x": 258,
#                     "y": 76
#                 },
#                 "leftMouth": {
#                     "x": 250,
#                     "y": 88
#                 },
#                 "rightMouth": {
#                     "x": 268,
#                     "y": 86
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.656963
#             },
#             "age": {
#                 "value": "80~84",
#                 "confidence": 0.242016
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.957067
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.979933
#             }
#         },
#         {
#             "roi": {
#                 "x": 136,
#                 "y": 136,
#                 "width": 36,
#                 "height": 36
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 144,
#                     "y": 142
#                 },
#                 "rightEye": {
#                     "x": 164,
#                     "y": 142
#                 },
#                 "nose": {
#                     "x": 155,
#                     "y": 151
#                 },
#                 "leftMouth": {
#                     "x": 147,
#                     "y": 161
#                 },
#                 "rightMouth": {
#                     "x": 163,
#                     "y": 162
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.997381
#             },
#             "age": {
#                 "value": "54~58",
#                 "confidence": 0.136841
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.996852
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.998287
#             }
#         },
#         {
#             "roi": {
#                 "x": 32,
#                 "y": 204,
#                 "width": 46,
#                 "height": 46
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 43,
#                     "y": 216
#                 },
#                 "rightEye": {
#                     "x": 64,
#                     "y": 213
#                 },
#                 "nose": {
#                     "x": 56,
#                     "y": 226
#                 },
#                 "leftMouth": {
#                     "x": 48,
#                     "y": 236
#                 },
#                 "rightMouth": {
#                     "x": 66,
#                     "y": 234
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.998743
#             },
#             "age": {
#                 "value": "27~31",
#                 "confidence": 0.210603
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.793047
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.7807
#             }
#         },
#         {
#             "roi": {
#                 "x": 204,
#                 "y": 264,
#                 "width": 32,
#                 "height": 32
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.787793
#             },
#             "age": {
#                 "value": "2~6",
#                 "confidence": 0.342641
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.944879
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.516906
#             }
#         },
#         {
#             "roi": {
#                 "x": 274,
#                 "y": 266,
#                 "width": 33,
#                 "height": 33
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 287,
#                     "y": 276
#                 },
#                 "rightEye": {
#                     "x": 299,
#                     "y": 275
#                 },
#                 "nose": {
#                     "x": 296,
#                     "y": 281
#                 },
#                 "leftMouth": {
#                     "x": 288,
#                     "y": 290
#                 },
#                 "rightMouth": {
#                     "x": 298,
#                     "y": 289
#                 }
#             },
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.611462
#             },
#             "age": {
#                 "value": "31~35",
#                 "confidence": 3.42814e-05
#             },
#             "emotion": {
#                 "value": "talking",
#                 "confidence": 0.984321
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.583783
#             }
#         },
#         {
#             "roi": {
#                 "x": 135,
#                 "y": 214,
#                 "width": 41,
#                 "height": 41
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 144,
#                     "y": 226
#                 },
#                 "rightEye": {
#                     "x": 163,
#                     "y": 227
#                 },
#                 "nose": {
#                     "x": 155,
#                     "y": 232
#                 },
#                 "leftMouth": {
#                     "x": 144,
#                     "y": 244
#                 },
#                 "rightMouth": {
#                     "x": 164,
#                     "y": 244
#                 }
#             },
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.986629
#             },
#             "age": {
#                 "value": "87~91",
#                 "confidence": 0.134264
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.714546
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999747
#             }
#         }
#     ]
# }

# %%
import matplotlib.patches as patches

img = mpimg.imread('face2.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

for each in parsed['faces']:

    x,y,w,h = each['roi'].values()
    gender,gen_confi = each['gender'].values()
    emotion,emo_confi = each['emotion'].values()
    age,age_confi = each['age'].values()
    
    
    rect_face = patches.Rectangle((x,y),w,h,
                             linewidth = 3,
                             edgecolor = 'r',
                             facecolor = 'none')
    ax.add_patch(rect_face)


    annotation = gender + " : " + str(round(gen_confi*100))+ '%' + '\n' + emotion + " : " + str(round(emo_confi*100))+ '%'  + '\n' + age + " ; " + str(round(age_confi*100)) 
    plt.text(x-15, y-30, annotation, wrap = True, fontsize = 10, color = 'white')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
